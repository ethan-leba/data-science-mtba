# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv("reliability_satisfaction_combine.csv")

# %% [markdown]
# ## This is visualizing the first hypothesis: Long arrival delays negatively affect customer satisfaction.

# %% [markdown]
# Here, long arrival delays are represented with wait time at stop which has a scale from 0 (don't need to wait at all) to 5 (long delays). The reliability of the all lines is simplified as "Ave_Month_RE_overall" which is the average of all lines' reliability in a month.

# %%
df
# Out:
#    service_date  Ave_Month_RE_overall  How would you rate the mbta overall?  \
# 0       2016-02              0.781771                                4.1678
# 1       2016-03              0.763396                                4.1228
# 2       2016-04              0.806854                                4.4165
# 3       2016-05              0.812263                                4.3533
# 4       2016-06              0.809461                                4.1126
# 5       2016-07              0.815754                                4.2524
# 6       2016-08              0.823135                                4.2914
# 7       2016-09              0.825981                                4.1774
# 8       2016-10              0.824028                                4.2722
# 9       2016-11              0.819190                                4.1511
# 10      2016-12              0.828300                                4.2486
# ...

# %%
import seaborn as sns
graph = sns.scatterplot(x="Ave_Month_RE_overall", y="How would you rate the mbta overall?", data = df)

# %%
import seaborn as sns

# create and display the line plot
graph = sns.lineplot(x="Ave_Month_RE_overall", y="How would you rate the mbta overall?", data = df)

#specify the title
title = "Reliability vs. ovreall satisfatcion"

#set the title of the plot
graph.set_title(title, size = 16)

#add labels to the axes  
graph.set_xlabel("Ave_Month_RE_overall", size = 16)
graph.set_ylabel("mbta overall rating", size = 16)
# Out:
# Text(0, 0.5, 'mbta overall rating')

# %%
# create and display the line plot
graph = sns.scatterplot(x="Ave_Month_RE_overall", y="Wait time at stop", data = df)

#specify the title
title = "Reliability vs. time of arrvials"

#set the title of the plot
graph.set_title(title, size = 16)

#add labels to the axes  
graph.set_xlabel("Ave_Month_RE_overall", size = 16)
graph.set_ylabel("Wait time at stop", size = 16)
# Out:
# Text(0, 0.5, 'Wait time at stop')

# %% [markdown]
# ## This is visualizing the second hypothesis: Congestion negatively affect customer satisfaction.

# %%
df = pd.read_csv("ridership_congestion_combine.csv")

# %%
df
# Out:
#      Unnamed: 0        date     ridership   train_line  Vehicle crowdedness
# 0             1  2016-02-01  1.220639e+06    Blue Line               3.5872
# 1             2  2016-02-01  3.752289e+06   Green Line               3.5872
# 2             3  2016-02-01  4.379649e+06  Orange Line               3.5872
# 3             4  2016-02-01  5.132032e+06     Red Line               3.5872
# 4             5  2016-03-01  1.510118e+06    Blue Line               3.4033
# ..          ...         ...           ...          ...                  ...
# 111         112  2018-05-01  5.652072e+06     Red Line               3.7196
# 112         113  2018-06-01  1.640592e+06    Blue Line               3.5537
# 113         114  2018-06-01  3.529725e+06   Green Line               3.5537
# 114         115  2018-06-01  4.476038e+06  Orange Line               3.5537
# 115         116  2018-06-01  5.357090e+06     Red Line               3.5537
#
# [116 rows x 5 columns]

# %%
graph = sns.lineplot(x="ridership", y="Vehicle crowdedness", hue="train_line", data = df)

# %%
import seaborn as sns

# create and display the line plot
graph = sns.lineplot(x="ridership", y="Vehicle crowdedness", hue="train_line", data = df)

#specify the title
title = "Ridership vs. Congestion"

#set the title of the plot
graph.set_title(title, size = 16)

#add labels to the axes  
graph.set_xlabel(title, size = 16)
# Out:
# Text(0.5, 0, 'Ridership vs. Congestion')
